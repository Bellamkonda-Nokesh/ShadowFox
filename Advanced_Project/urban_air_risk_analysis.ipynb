# %% [markdown]
# # Urban Air Quality Risk Prediction
#
# Air pollution poses a serious health risk in urban areas.
# This project analyzes air quality and environmental factors
# to identify and classify high-risk pollution days.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
df = pd.read_csv("UrbanAirPollutionDataset.csv")
df.head()
# Out:
#    Station_ID             DateTime      PM2.5        PM10        NO₂  \
# 0           1  2020-01-01 00:00:00  86.397213  111.814972  26.599649
# 1           1  2020-01-01 01:00:00  73.311679  110.919391  18.585412
# 2           1  2020-01-01 02:00:00  61.359818   47.063317  20.605215
# 3           1  2020-01-01 03:00:00  54.081632  122.981322  14.682654
# 4           1  2020-01-01 04:00:00  43.221175  102.259959  41.515463
#
#          SO₂        CO         O₃     Temp_C  Humidity_%  Wind_Speed_mps  \
# 0   3.875088  0.570793  42.903768  31.491409   45.704988        3.114026
# 1  11.820056  0.562121  15.127661  24.191965   41.544655        3.480094
# 2  16.531417  0.466105  32.752213  30.719383   73.849227        4.949460
# 3  14.453442  0.607025  18.910033  18.243150   42.086443        1.834147
# 4  17.495670  0.537119  39.582884  33.949777   42.393921        1.987593
#
#    Wind_Direction_deg  Pressure_hPa  Rain_mm  AQI_Target
# 0          166.148254   1012.641964      1.0   59.759255
# 1          282.158060   1011.779447      0.0   45.256996
# 2          109.450898   1004.118484      0.0   43.411916
# 3          229.796006   1009.154244      0.0   35.227619
# 4          159.501370   1021.100094      0.0   41.981803

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.columns
# Out:
# Index(['station_id', 'datetime', 'pm2.5', 'pm10', 'no₂', 'so₂', 'co', 'o₃',
#        'temp_c', 'humidity_%', 'wind_speed_mps', 'wind_direction_deg',
#        'pressure_hpa', 'rain_mm', 'aqi_target'],
#       dtype='str')

# %%
df["datetime"] = pd.to_datetime(df["datetime"])
df["month"] = df["datetime"].dt.month
df["year"] = df["datetime"].dt.year

df["season"] = df["month"].map({
    12: "Winter", 1: "Winter", 2: "Winter",
    3: "Summer", 4: "Summer", 5: "Summer",
    6: "Monsoon", 7: "Monsoon", 8: "Monsoon",
    9: "Post-Monsoon", 10: "Post-Monsoon", 11: "Post-Monsoon"
})

df.head()
# Out:
#    station_id            datetime      pm2.5        pm10        no₂  \
# 0           1 2020-01-01 00:00:00  86.397213  111.814972  26.599649
# 1           1 2020-01-01 01:00:00  73.311679  110.919391  18.585412
# 2           1 2020-01-01 02:00:00  61.359818   47.063317  20.605215
# 3           1 2020-01-01 03:00:00  54.081632  122.981322  14.682654
# 4           1 2020-01-01 04:00:00  43.221175  102.259959  41.515463
#
#          so₂        co         o₃     temp_c  humidity_%  wind_speed_mps  \
# 0   3.875088  0.570793  42.903768  31.491409   45.704988        3.114026
# 1  11.820056  0.562121  15.127661  24.191965   41.544655        3.480094
# 2  16.531417  0.466105  32.752213  30.719383   73.849227        4.949460
# 3  14.453442  0.607025  18.910033  18.243150   42.086443        1.834147
# 4  17.495670  0.537119  39.582884  33.949777   42.393921        1.987593
#
#    wind_direction_deg  pressure_hpa  rain_mm  aqi_target  month  year  season
# 0          166.148254   1012.641964      1.0   59.759255      1  2020  Winter
# 1          282.158060   1011.779447      0.0   45.256996      1  2020  Winter
# 2          109.450898   1004.118484      0.0   43.411916      1  2020  Winter
# 3          229.796006   1009.154244      0.0   35.227619      1  2020  Winter
# 4          159.501370   1021.100094      0.0   41.981803      1  2020  Winter

# %%
df["date"] = df["datetime"]
df["month"] = df["date"].dt.month
df["year"] = df["date"].dt.year

df["season"] = df["month"].map({
    12: "Winter", 1: "Winter", 2: "Winter",
    3: "Summer", 4: "Summer", 5: "Summer",
    6: "Monsoon", 7: "Monsoon", 8: "Monsoon",
    9: "Post-Monsoon", 10: "Post-Monsoon", 11: "Post-Monsoon"
})

df.head()
# Out:
#    station_id            datetime      pm2.5        pm10        no₂  \
# 0           1 2020-01-01 00:00:00  86.397213  111.814972  26.599649
# 1           1 2020-01-01 01:00:00  73.311679  110.919391  18.585412
# 2           1 2020-01-01 02:00:00  61.359818   47.063317  20.605215
# 3           1 2020-01-01 03:00:00  54.081632  122.981322  14.682654
# 4           1 2020-01-01 04:00:00  43.221175  102.259959  41.515463
#
#          so₂        co         o₃     temp_c  humidity_%  wind_speed_mps  \
# 0   3.875088  0.570793  42.903768  31.491409   45.704988        3.114026
# 1  11.820056  0.562121  15.127661  24.191965   41.544655        3.480094
# 2  16.531417  0.466105  32.752213  30.719383   73.849227        4.949460
# 3  14.453442  0.607025  18.910033  18.243150   42.086443        1.834147
# 4  17.495670  0.537119  39.582884  33.949777   42.393921        1.987593
#
#    wind_direction_deg  pressure_hpa  rain_mm  aqi_target  month  year  season  \
# 0          166.148254   1012.641964      1.0   59.759255      1  2020  Winter
# 1          282.158060   1011.779447      0.0   45.256996      1  2020  Winter
# 2          109.450898   1004.118484      0.0   43.411916      1  2020  Winter
# 3          229.796006   1009.154244      0.0   35.227619      1  2020  Winter
# 4          159.501370   1021.100094      0.0   41.981803      1  2020  Winter
#
#                  date
# 0 2020-01-01 00:00:00
# 1 2020-01-01 01:00:00
# 2 2020-01-01 02:00:00
# 3 2020-01-01 03:00:00
# 4 2020-01-01 04:00:00

# %%
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# %%
def risk_label(aqi):
    if aqi <= 100:
        return "Low Risk"
    elif aqi <= 200:
        return "Medium Risk"
    else:
        return "High Risk"

df["risk_level"] = df["aqi_target"].apply(risk_label)
df["risk_level"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'aqi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 9
#       6     else:
#       7         return "High Risk"
# ----> 9 df["risk_level"] = df["aqi"].apply(risk_label)
#      10 df["risk_level"].value_counts()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'aqi'
